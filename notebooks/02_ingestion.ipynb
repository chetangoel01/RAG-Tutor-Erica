# %% [markdown]
# # M2: Ingestion Pipeline
#
# This notebook runs the course website crawler and displays all ingested URLs.
#
# ## Prerequisites
# - MongoDB running (via docker-compose)
# - Network access to https://pantelis.github.io/courses/ai/

# %%
# Add src to path
import sys
sys.path.insert(0, '/app')

from src.ingestion import Crawler, Storage, COURSE_ROOT

# %% [markdown]
# ## 1. Initialize Storage
#
# Connect to MongoDB and check current state.

# %%
# Connect to MongoDB
storage = Storage(
    mongo_uri='mongodb://erica:erica_password_123@mongodb:27017/',
    db_name='erica'
)

# Check current stats
stats = storage.get_stats()
print("Current database state:")
print(f"  Pages: {stats['pages']}")
print(f"  Resources: {stats['resources']['total']}")
print(f"  Failures: {stats['failures']}")
# Out:
# Current database state:
#   Pages: 184
#   Resources: 1317
#   Failures: 55

# %% [markdown]
# ## 2. Run Crawler (Optional)
#
# ⚠️ Only run this cell if you want to (re)crawl the website. Takes several minutes.

# %%
# # Uncomment to clear existing data first
# storage.clear_all()
# print("Cleared existing data")

# %%
# Run the crawler
crawler = Crawler(
    storage=storage,
    delay=0.2,  # 0.1 seconds between requests
    progress_interval=10  # Log every 10 pages
)

# Start crawling from course root
crawler.crawl(COURSE_ROOT)
# Out:
# [INFO] Starting crawl from https://pantelis.github.io/courses/ai/
# [INFO] [1] https://pantelis.github.io/courses/ai - 17 internal, 0 pdfs, 1 images
# [INFO] [2] https://pantelis.github.io/book/foundations/index.html - 26 internal, 0 pdfs, 6 images
# [INFO] [3] https://pantelis.github.io/book/dnn/index.html - 26 internal, 0 pdfs, 6 images
# [INFO] [4] https://pantelis.github.io/book/2d-perception/index.html - 36 internal, 0 pdfs, 10 images
# [INFO] [5] https://pantelis.github.io/book/kinematics/index.html - 22 internal, 3 pdfs, 2 images
# [INFO] [6] https://pantelis.github.io/book/state-estimation/index.html - 20 internal, 0 pdfs, 2 images
# [INFO] [7] https://pantelis.github.io/book/llm/index.html - 40 internal, 0 pdfs, 10 images
# [INFO] [8] https://pantelis.github.io/book/multimodal/index.html - 34 internal, 0 pdfs, 6 images
# [INFO] [9] https://pantelis.github.io/book/task-planning/index.html - 19 internal, 0 pdfs, 3 images
# [INFO] [10] https://pantelis.github.io/book/global-planning/index.html - 19 internal, 0 pdfs, 3 images
# [INFO] Progress: 10 pages done, 205 in queue, 0 resources found
# [WARNING] Crawl interrupted by user
# [INFO]
# [INFO] ==================================================
# [INFO] CRAWL COMPLETE
# [INFO] ==================================================
# [INFO] Time elapsed: 3.9s
# [INFO] Pages ingested: 184
# [INFO] Images downloaded: 613
# [INFO] PDFs discovered: 42
# [INFO] Videos discovered: 11
# [INFO] Failures logged: 27
# [INFO]   (run db.failures.find() to review)
# [INFO] ==================================================

# %% [markdown]
# ## 3. View Ingested URLs
#
# This satisfies the M2 requirement: "Ensure you have a notebook cell / markdown file that prints all the URLs that you have ingested."

# %%
# Get all URLs
urls = storage.get_all_urls()

print("=" * 60)
print("ALL INGESTED URLs")
print("=" * 60)
# Out:
# ============================================================
# ALL INGESTED URLs
# ============================================================

# %%
# Pages
print(f"\n📄 WEB PAGES ({len(urls['pages'])})")
print("-" * 40)
for url in sorted(urls['pages']):
    print(url)
# Out:
# 📄 WEB PAGES (184)
# ----------------------------------------
# https://pantelis.github.io/aiml-common/assignments/main/ai-fall-2025/assignment-1-grad.html
# https://pantelis.github.io/aiml-common/assignments/main/ai-fall-2025/assignment-1-undergrad.html
# https://pantelis.github.io/aiml-common/assignments/main/ai-fall-2025/assignment-2.html
# https://pantelis.github.io/aiml-common/assignments/main/ai-fall-2025/assignment-3.html
# https://pantelis.github.io/aiml-common/assignments/main/ai-fall-2025/assignment-4.html
# https://pantelis.github.io/aiml-common/assignments/topics/cnn-explainers/index-2-preview.html
# https://pantelis.github.io/aiml-common/assignments/topics/cnn-explainers/index-2.ipynb
# https://pantelis.github.io/aiml-common/assignments/topics/devenv/index-preview.html
# https://pantelis.github.io/aiml-common/assignments/topics/devenv/index.ipynb
# https://pantelis.github.io/aiml-common/assignments/topics/dim-reduction/curse-dimensionality-preview.html
# https://pantelis.github.io/aiml-common/assignments/topics/dim-reduction/curse-dimensionality.ipynb
# https://pantelis.github.io/aiml-common/assignments/topics/logistic-regression/ctr-preview.html
# https://pantelis.github.io/aiml-common/assignments/topics/logistic-regression/ctr.ipynb
# https://pantelis.github.io/aiml-common/assignments/topics/mle/gaussian/mle-gmm-sgd-preview.html
# https://pantelis.github.io/aiml-common/assignments/topics/object-tracking-kalman/soccer-preview.html
# https://pantelis.github.io/aiml-common/assignments/topics/object-tracking-kalman/soccer.ipynb
# https://pantelis.github.io/aiml-common/assignments/topics/sports-analytics/basketball/index-preview.html
# https://pantelis.github.io/aiml-common/lectures/VLA/advances.html
# https://pantelis.github.io/aiml-common/lectures/VLM/blip-2/index.html
# https://pantelis.github.io/aiml-common/lectures/VLM/blip-2/paper.html
# https://pantelis.github.io/aiml-common/lectures/VLM/clip/index.html
# https://pantelis.github.io/aiml-common/lectures/VLM/clip/paper.html
# https://pantelis.github.io/aiml-common/lectures/VLM/llava/index.html
# https://pantelis.github.io/aiml-common/lectures/VLM/llava/paper.html
# https://pantelis.github.io/aiml-common/lectures/classification/classification-intro/index.html
# https://pantelis.github.io/aiml-common/lectures/classification/logistic-regression/index.html
# https://pantelis.github.io/aiml-common/lectures/cnn/cnn-example-architectures/index.html
# https://pantelis.github.io/aiml-common/lectures/cnn/cnn-example-architectures/using_convnets_with_small_datasets.html
# https://pantelis.github.io/aiml-common/lectures/cnn/cnn-example-architectures/visualizing-what-convnets-learn.html
# https://pantelis.github.io/aiml-common/lectures/cnn/cnn-intro/index.html
# https://pantelis.github.io/aiml-common/lectures/cnn/cnn-layers/index.html
# https://pantelis.github.io/aiml-common/lectures/dnn/backprop-dnn-exercises/index.html
# https://pantelis.github.io/aiml-common/lectures/dnn/backprop-dnn/index.html
# https://pantelis.github.io/aiml-common/lectures/dnn/backprop-intro/index.html
# https://pantelis.github.io/aiml-common/lectures/dnn/dnn-intro/index.html
# https://pantelis.github.io/aiml-common/lectures/dnn/fashion-mnist-case-study.html
# https://pantelis.github.io/aiml-common/lectures/empirical-risk/index.html
# https://pantelis.github.io/aiml-common/lectures/entropy/index.html
# https://pantelis.github.io/aiml-common/lectures/introductions/agents/index.html
# https://pantelis.github.io/aiml-common/lectures/introductions/ai-course-introduction/index.html
# https://pantelis.github.io/aiml-common/lectures/kinematics/configuration-space/index.html
# https://pantelis.github.io/aiml-common/lectures/kinematics/configuration-space/lynch.html
# https://pantelis.github.io/aiml-common/lectures/kinematics/motion-representations/index.html
# https://pantelis.github.io/aiml-common/lectures/kinematics/motion-representations/lynch.html
# https://pantelis.github.io/aiml-common/lectures/kinematics/motion-representations/representations.html
# https://pantelis.github.io/aiml-common/lectures/kinematics/wheeled-robots/lynch.html
# https://pantelis.github.io/aiml-common/lectures/kinematics/wheeled-robots/wheeled-robot-models.html
# https://pantelis.github.io/aiml-common/lectures/learning-problem/index.html
# https://pantelis.github.io/aiml-common/lectures/logical-reasoning/automated-reasoning/index.html
# https://pantelis.github.io/aiml-common/lectures/logical-reasoning/index.html
# https://pantelis.github.io/aiml-common/lectures/logical-reasoning/logical-agents/index.html
# https://pantelis.github.io/aiml-common/lectures/logical-reasoning/logical-inference/index.html
# https://pantelis.github.io/aiml-common/lectures/logical-reasoning/propositional-logic/index.html
# https://pantelis.github.io/aiml-common/lectures/mdp/bellman-expectation-backup/index.html
# https://pantelis.github.io/aiml-common/lectures/mdp/bellman-optimality-backup/index.html
# https://pantelis.github.io/aiml-common/lectures/mdp/dynamic-programming-algorithms/policy-iteration/index.html
# https://pantelis.github.io/aiml-common/lectures/mdp/dynamic-programming-algorithms/policy-iteration/policy-iteration-gridworld.html
# https://pantelis.github.io/aiml-common/lectures/mdp/dynamic-programming-algorithms/value-iteration/index.html
# https://pantelis.github.io/aiml-common/lectures/mdp/dynamic-programming-algorithms/value-iteration/value-iteration-gridworld.html
# https://pantelis.github.io/aiml-common/lectures/mdp/index.html
# https://pantelis.github.io/aiml-common/lectures/mdp/mdp-intro/mdp_intro.html
# https://pantelis.github.io/aiml-common/lectures/mdp/mdp-workshop/cleaning-robot/deterministic_mdp.html
# https://pantelis.github.io/aiml-common/lectures/mdp/mdp-workshop/cleaning-robot/stochastic_mdp.html
# https://pantelis.github.io/aiml-common/lectures/mdp/mdp-workshop/recycling-robot/index.html
# https://pantelis.github.io/aiml-common/lectures/mdp/policy-evaluation/index.html
# https://pantelis.github.io/aiml-common/lectures/mdp/policy-improvement/index.html
# https://pantelis.github.io/aiml-common/lectures/ml-math/calculus/index.html
# https://pantelis.github.io/aiml-common/lectures/ml-math/index.html
# https://pantelis.github.io/aiml-common/lectures/ml-math/linear-algebra/index.html
# https://pantelis.github.io/aiml-common/lectures/ml-math/probability/index.html
# https://pantelis.github.io/aiml-common/lectures/nlp/language-models/cnn-language-model/index.html
# https://pantelis.github.io/aiml-common/lectures/nlp/language-models/index.html
# https://pantelis.github.io/aiml-common/lectures/nlp/language-models/inference/index.html
# https://pantelis.github.io/aiml-common/lectures/nlp/language-models/lstm-language-model/index.html
# https://pantelis.github.io/aiml-common/lectures/nlp/language-models/rnn-language-model/index.html
# https://pantelis.github.io/aiml-common/lectures/nlp/language-models/simple-rnn-language-model/index.html
# https://pantelis.github.io/aiml-common/lectures/nlp/nlp-introduction/nlp-pipelines/index.html
# https://pantelis.github.io/aiml-common/lectures/nlp/nlp-introduction/tokenization/index.html
# https://pantelis.github.io/aiml-common/lectures/nlp/nlp-introduction/word2vec/index.html
# https://pantelis.github.io/aiml-common/lectures/nlp/nlp-introduction/word2vec/word2vec_from_scratch.html
# https://pantelis.github.io/aiml-common/lectures/nlp/nlp-introduction/word2vec/word2vec_tensorflow_tutorial.html
# https://pantelis.github.io/aiml-common/lectures/nlp/nmt/nmt-intro/index.html
# https://pantelis.github.io/aiml-common/lectures/nlp/nmt/nmt-metrics/index.html
# https://pantelis.github.io/aiml-common/lectures/nlp/nmt/rnn-attention-workshop/seq2seq_and_attention.ipynb
# https://pantelis.github.io/aiml-common/lectures/nlp/nmt/rnn-nmt-attention/index.html
# https://pantelis.github.io/aiml-common/lectures/nlp/nmt/rnn-nmt-workshop/lstm_seq2seq.html
# https://pantelis.github.io/aiml-common/lectures/nlp/transformers/mlp.html
# https://pantelis.github.io/aiml-common/lectures/nlp/transformers/multihead-self-attention.html
# https://pantelis.github.io/aiml-common/lectures/nlp/transformers/positional_embeddings.html
# https://pantelis.github.io/aiml-common/lectures/nlp/transformers/singlehead-self-attention.html
# https://pantelis.github.io/aiml-common/lectures/nlp/transformers/transformers-intro.html
# https://pantelis.github.io/aiml-common/lectures/optimization/batch-normalization/index.html
# https://pantelis.github.io/aiml-common/lectures/optimization/layer-normalization/index.html
# https://pantelis.github.io/aiml-common/lectures/optimization/maximum-likelihood/conditional_maximum_likelihood.html
# https://pantelis.github.io/aiml-common/lectures/optimization/maximum-likelihood/marginal_maximum_likelihood.html
# https://pantelis.github.io/aiml-common/lectures/optimization/maximum-likelihood/mle-gaussian-parameters.html
# https://pantelis.github.io/aiml-common/lectures/optimization/regularization/index.html
# https://pantelis.github.io/aiml-common/lectures/optimization/sgd/index.html
# https://pantelis.github.io/aiml-common/lectures/optimization/whitening/corr-cov-matrix.html
# https://pantelis.github.io/aiml-common/lectures/optimization/whitening/index.html
# https://pantelis.github.io/aiml-common/lectures/planning/global-planning/search/a-star/a-star.html
# https://pantelis.github.io/aiml-common/lectures/planning/global-planning/search/a-star/index.html
# https://pantelis.github.io/aiml-common/lectures/planning/global-planning/search/forward-search/index.html
# https://pantelis.github.io/aiml-common/lectures/planning/global-planning/search/index.html
# https://pantelis.github.io/aiml-common/lectures/planning/local-planning/behavioral-planning/index.html
# https://pantelis.github.io/aiml-common/lectures/planning/local-planning/motion-planning/index.html
# https://pantelis.github.io/aiml-common/lectures/planning/local-planning/prediction/index.html
# https://pantelis.github.io/aiml-common/lectures/planning/task-planning/index.html
# https://pantelis.github.io/aiml-common/lectures/planning/task-planning/pddl/blocksworld/up_blocksworld_demo.html
# https://pantelis.github.io/aiml-common/lectures/planning/task-planning/pddl/index.html
# https://pantelis.github.io/aiml-common/lectures/planning/task-planning/pddl/logistics/index.html
# https://pantelis.github.io/aiml-common/lectures/planning/task-planning/pddl/manufacturing/index.html
# https://pantelis.github.io/aiml-common/lectures/python/index.html
# https://pantelis.github.io/aiml-common/lectures/regression/linear-regression/index.html
# https://pantelis.github.io/aiml-common/lectures/regression/linear-regression/sgd_sinusoidal_dataset.html
# https://pantelis.github.io/aiml-common/lectures/regression/linear-regression/sgd_sinusoidal_dataset.out.ipynb
# https://pantelis.github.io/aiml-common/lectures/reinforcement-learning/index.html
# https://pantelis.github.io/aiml-common/lectures/reinforcement-learning/model-free-control/generalized-policy-iteration/index.html
# https://pantelis.github.io/aiml-common/lectures/reinforcement-learning/model-free-control/greedy-monte-carlo/index.html
# https://pantelis.github.io/aiml-common/lectures/reinforcement-learning/model-free-control/sarsa/gridworld/sarsa_gridworld.html
# https://pantelis.github.io/aiml-common/lectures/reinforcement-learning/model-free-control/sarsa/index.html
# https://pantelis.github.io/aiml-common/lectures/reinforcement-learning/prediction/monte-carlo.html
# https://pantelis.github.io/aiml-common/lectures/reinforcement-learning/prediction/td-vs-mc-mrp.html
# https://pantelis.github.io/aiml-common/lectures/reinforcement-learning/prediction/temporal-difference.html
# https://pantelis.github.io/aiml-common/lectures/rnn/introduction/index.html
# https://pantelis.github.io/aiml-common/lectures/rnn/lstm/index.html
# https://pantelis.github.io/aiml-common/lectures/rnn/simple-rnn/index.html
# https://pantelis.github.io/aiml-common/lectures/rnn/time_series_using_simple_rnn_lstm.html
# https://pantelis.github.io/aiml-common/lectures/rse/discrete-bayesian-filter/discrete-bayesian-filter.html
# https://pantelis.github.io/aiml-common/lectures/rse/hmm-localization/index.html
# https://pantelis.github.io/aiml-common/lectures/rse/kalman-filters/one-dimensional-kalman-filters.html
# https://pantelis.github.io/aiml-common/lectures/rse/occupancy-mapping/index.html
# https://pantelis.github.io/aiml-common/lectures/rse/recursive-state-estimation/index.html
# https://pantelis.github.io/aiml-common/lectures/rse/slam/index.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/feature-extraction-resnet/index.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/object-detection/detection-metrics/index.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/object-detection/fast-rcnn/index.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/object-detection/faster-rcnn/index.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/object-detection/object-detection-intro/index.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/object-detection/rcnn/index.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/object-detection/rcnn/nms_example-preview.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/object-detection/rcnn/nms_example.ipynb
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/object-detection/yolo/introduction.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/scene-understanding-intro/index.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/semantic-segmentation/maskrcnn/index.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/semantic-segmentation/maskrcnn/pytorch/detectron_tutorial.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/semantic-segmentation/maskrcnn/pytorch/maskrcnn_detectron.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/semantic-segmentation/maskrcnn/pytorch/maskrcnn_torchvision_inference.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/semantic-segmentation/maskrcnn/tf/demo.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/semantic-segmentation/maskrcnn/tf/inspect_data.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/semantic-segmentation/maskrcnn/tf/inspect_model.html
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/semantic-segmentation/maskrcnn/tf/inspect_weights
# https://pantelis.github.io/aiml-common/lectures/scene-understanding/semantic-segmentation/maskrcnn/tf/inspect_weights.html
# https://pantelis.github.io/aiml-common/lectures/sensor-models/beam/index.html
# https://pantelis.github.io/aiml-common/lectures/sensor-models/cameras/camera-calibration.html
# https://pantelis.github.io/aiml-common/lectures/sensor-models/cameras/index.html
# https://pantelis.github.io/aiml-common/lectures/sensor-models/cameras/pinhole-model.html
# https://pantelis.github.io/aiml-common/lectures/sensor-models/cameras/zhang-calibration-alg.html
# https://pantelis.github.io/aiml-common/lectures/transfer-learning/transfer-learning-introduction.html
# https://pantelis.github.io/aiml-common/lectures/transfer-learning/transfer_learning_tutorial.html
# https://pantelis.github.io/aiml-common/lectures/vision-transformers/paper.html
# https://pantelis.github.io/aiml-common/lectures/vision-transformers/vision_transformer_tutorial.html
# https://pantelis.github.io/aiml-common/projects/nlp/ai-tutor/index.html
# https://pantelis.github.io/aiml-common/resources/environment/assignment-submission.html
# https://pantelis.github.io/aiml-common/resources/environment/index.html
# https://pantelis.github.io/book/2d-perception/index.html
# https://pantelis.github.io/book/dnn/index.html
# https://pantelis.github.io/book/foundations/index.html
# https://pantelis.github.io/book/global-planning/index.html
# https://pantelis.github.io/book/kinematics/index.html
# https://pantelis.github.io/book/llm/index.html
# https://pantelis.github.io/book/local-planning/index.html
# https://pantelis.github.io/book/logical-reasoning/index.html
# https://pantelis.github.io/book/mdp/index.html
# https://pantelis.github.io/book/multimodal/index.html
# https://pantelis.github.io/book/rl/index.html
# https://pantelis.github.io/book/state-estimation/index.html
# https://pantelis.github.io/book/task-planning/index.html
# https://pantelis.github.io/book/vla/index.html
# https://pantelis.github.io/courses/ai
# https://pantelis.github.io/courses/ai/in-person.html
# https://pantelis.github.io/courses/ai/index.html
# https://pantelis.github.io/courses/ai/online.html
# https://pantelis.github.io/courses/ai/syllabus/index.html

# %%
# PDFs
print(f"\n📕 PDF DOCUMENTS ({len(urls['pdfs'])})")
print("-" * 40)
for url in sorted(urls['pdfs']):
    print(url)
# Out:
# 📕 PDF DOCUMENTS (42)
# ----------------------------------------
# http://algorithmics.lsi.upc.edu/docs/Dasgupta-Papadimitriou-Vazirani.pdf
# http://alvyray.com/CreativeCommons/BizCardUniversalTuringMachine_v2.3.pdf
# http://cs231n.stanford.edu/handouts/derivatives.pdf
# http://cs231n.stanford.edu/slides/2018/cs231n_2018_lecture10.pdf
# http://cs231n.stanford.edu/vecDerivs.pdf
# http://hosting.astro.cornell.edu/~cordes/A6523/GeneratingCorrelatedRandomVariables.pdf
# http://incompleteideas.net/book/RLbook2020.pdf
# http://math.mit.edu/~gs/linearalgebra/linearalgebra5_6-1.pdf
# http://proceedings.mlr.press/v28/pascanu13.pdf
# http://www.cs.toronto.edu/~rsalakhu/papers/srivastava14a.pdf
# http://yann.lecun.com/exdb/publis/pdf/lecun-98b.pdf
# https://arxiv.org/pdf/1301.3781.pdf
# https://arxiv.org/pdf/1312.4400v3.pdf
# https://arxiv.org/pdf/1409.1556.pdf
# https://arxiv.org/pdf/1412.6806.pdf
# https://arxiv.org/pdf/1503.04069v1.pdf
# https://arxiv.org/pdf/1506.00019.pdf
# https://arxiv.org/pdf/1605.06431.pdf
# https://arxiv.org/pdf/1704.04503.pdf
# https://arxiv.org/pdf/1801.05134.pdf
# https://arxiv.org/pdf/1802.01528.pdf
# https://arxiv.org/pdf/1901.06958.pdf
# https://icaps23.icaps-conference.org/demos/papers/6374_paper.pdf
# https://kaiminghe.github.io/icml16tutorial/icml2016_tutorial_deep_residual_networks_kaiminghe.pdf
# https://mml-book.github.io/book/mml-book.pdf
# https://pandas.pydata.org/pandas-docs/stable/pandas.pdf
# https://pantelis.github.io/aiml-common/lectures/kinematics/configuration-space/assets/pdf/lynch-config-space.pdf
# https://pantelis.github.io/aiml-common/lectures/optimization/maximum-likelihood/notescs6140linearregression.pdf
# https://pantelis.github.io/assets/pdf/camera-calibration-slides.pdf
# https://pantelis.github.io/assets/pdf/lynch-body-motions.pdf
# https://pantelis.github.io/assets/pdf/lynch-wheeled-robots.pdf
# https://pantelis.github.io/assets/pdf/zhang-camera-calibration.pdf
# https://pantelis.github.io/book/kinematics/assets/pdf/lynch-config-space.pdf
# https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf
# https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Numpy_Python_Cheat_Sheet.pdf
# https://web.stanford.edu/class/archive/cs/cs224n/cs224n.1194/readings/cs224n-2019-notes06-NMT_seq2seq_attention.pdf
# https://web.stanford.edu/class/cs224n/readings/cs224n-2019-notes01-wordvecs1.pdf
# https://web.stanford.edu/class/cs224n/readings/gradient-notes.pdf
# https://web.stanford.edu/~lmackey/stats306b/doc/stats306b-spring14-lecture2_scribed.pdf
# https://www.aaai.org/Papers/ICAPS/2003/ICAPS03-019.pdf
# https://www.aclweb.org/anthology/P18-1238.pdf
# https://www.computer.org/csdl/proceedings/iccv/2009/4420/00/05459469.pdf

# %%
# Videos
print(f"\n🎥 YOUTUBE VIDEOS ({len(urls['videos'])})")
print("-" * 40)
for url in sorted(urls['videos']):
    print(url)
# Out:
# 🎥 YOUTUBE VIDEOS (11)
# ----------------------------------------
# https://www.youtube.com/playlist?list=PLZHQObOWTQDPD3MizzM2xVFitgF8hE_ab
# https://www.youtube.com/watch?v=2pWv7GOvuf0&list=PLqYmG7hTraZDM-OYHWgPebj2MfCFzFObQ
# https://www.youtube.com/watch?v=6niqTuYFZLQ&t=521s
# https://www.youtube.com/watch?v=Cx5Z-OslNWE&list=PLUl4u3cNGP63oMNUHXqIUcrkS2PivhN3k
# https://www.youtube.com/watch?v=DiOxbYTLXX8
# https://www.youtube.com/watch?v=MMxMeX5emUA
# https://www.youtube.com/watch?v=Nd1-UUMVfz4&list=PLqYmG7hTraZDM-OYHWgPebj2MfCFzFObQ&index=3
# https://www.youtube.com/watch?v=WCUNPb-5EYI
# https://www.youtube.com/watch?v=hzaG2Uq60uw
# https://www.youtube.com/watch?v=x6wsTFnU3eY
# https://youtu.be/_NOVa4i7Us8?list=PL1Q0jeuU6XppS_r2Sa9fzVanpbXKqLsYS&t=384

# %%
# Images (just count, can expand if needed)
print(f"\n🖼️  IMAGES ({len(urls['images'])})")
print("-" * 40)
print(f"Total images downloaded: {len(urls['images'])}")
print("\nFirst 10 images:")
for url in sorted(urls['images'])[:10]:
    print(f"  {url}")
if len(urls['images']) > 10:
    print(f"  ... and {len(urls['images']) - 10} more")
# Out:
# 🖼️  IMAGES (613)
# ----------------------------------------
# Total images downloaded: 613
#
# First 10 images:
#   https://colab.research.google.com/assets/colab-badge.svg
#   https://dl.fbaipublicfiles.com/detectron2/Detectron2-Logo-Horz.png
#   https://drive.google.com/uc?id=12ha59vACcd8eCEPAQdbZ4-axPGPKnn7F
#   https://img.youtube.com/vi/x6wsTFnU3eY/0.jpg
#   https://pantelis.github.io/aiml-common/assignments/topics/cnn-explainers/workflow.png
#   https://pantelis.github.io/aiml-common/assignments/topics/sports-analytics/basketball/images/birdseye.png
#   https://pantelis.github.io/aiml-common/lectures/VLM/clip/images/arrowhead_ball.png
#   https://pantelis.github.io/aiml-common/lectures/VLM/clip/images/circle_triangle.png
#   https://pantelis.github.io/aiml-common/lectures/VLM/clip/images/clip_inference_fig.png
#   https://pantelis.github.io/aiml-common/lectures/VLM/clip/images/clip_mapping_diagram_two_branch.png
#   ... and 603 more

# %% [markdown]
# ## 4. View Statistics

# %%
stats = storage.get_stats()

print("\n📊 INGESTION STATISTICS")
print("=" * 40)
print(f"Pages ingested:     {stats['pages']}")
print(f"\nResources by type:")
print(f"  PDFs:             {stats['resources']['by_type']['pdf']}")
print(f"  Videos:           {stats['resources']['by_type']['video']}")
print(f"  Images:           {stats['resources']['by_type']['image']}")
print(f"  External links:   {stats['resources']['by_type']['external']}")
print(f"\nResources by status:")
print(f"  Pending:          {stats['resources']['by_status']['pending']}")
print(f"  Ingested:         {stats['resources']['by_status']['ingested']}")
print(f"  Failed:           {stats['resources']['by_status']['failed']}")
print(f"\nFailures logged:    {stats['failures']}")
# Out:
# 📊 INGESTION STATISTICS
# ========================================
# Pages ingested:     184
#
# Resources by type:
#   PDFs:             42
#   Videos:           11
#   Images:           613
#   External links:   651
#
# Resources by status:
#   Pending:          53
#   Ingested:         613
#   Failed:           0
#
# Failures logged:    27

# %% [markdown]
# ## 5. Review Failures (if any)

# %%
# Check for failures
failures = list(storage.failures.find())

if failures:
    print(f"\n⚠️  FAILURES ({len(failures)})")
    print("=" * 40)
    for f in failures:
        print(f"\nURL: {f['url']}")
        print(f"  Type: {f['failure_type']}")
        print(f"  Error: {f['error_message']}")
        print(f"  Attempts: {f['attempts']}")
else:
    print("\n✅ No failures recorded!")
# Out:
# ⚠️  FAILURES (27)
# ========================================
#
# URL: https://pantelis.github.io/courses/images/llama.jpeg
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 2
#
# URL: https://pantelis.github.io/aiml-common/lectures/classification/perceptron/index.qmd
#   Type: http_error
#   Error: Page not found
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/cnn/cnn-intro/index.md
#   Type: http_error
#   Error: Page not found
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/figs/pitchyawroll.svg
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 1
#
# URL: https://raw.githubusercontent.com/NxRLab/ModernRobotics/master/packages/python/doc/images/Chapter3/3.5_rodrigues.png
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/kinematics/motion-representations/.png
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/kinematics/wheeled-robots/index.qmd
#   Type: http_error
#   Error: Page not found
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/rse/discrete-bayesian-filter/animations/02_no_info.gif
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/rse/kalman-filters/animations/05_dog_track.gif
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/rse/kalman-filters/figs/residual_chart.png
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/rse/kalman-filters/animations/05_volt_animate.gif
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 1
#
# URL: https://tensorflow.org/tutorials/text/images/word2vec_skipgram.png
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 1
#
# URL: https://tensorflow.org/tutorials/text/images/word2vec_skipgram_objective.png
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 1
#
# URL: https://tensorflow.org/tutorials/text/images/word2vec_full_softmax.png
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 1
#
# URL: https://tensorflow.org/tutorials/text/images/word2vec_negative_sampling.png
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/nlp/nlp-introduction/word2vec/index.md
#   Type: http_error
#   Error: Page not found
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/vision-transformers/index.qmd
#   Type: http_error
#   Error: Page not found
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/planning/global-planning/index.qmd
#   Type: http_error
#   Error: Page not found
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/mdp/dynamic-programming-algorithms/index.qmd
#   Type: http_error
#   Error: Page not found
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/mdp/mdp-workshop/index.qmd
#   Type: http_error
#   Error: Page not found
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/assignments/main/ai-fall-2025/images/birdseye.png
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/transfer-learning/transfer-learning-introduction.md
#   Type: http_error
#   Error: Page not found
#   Attempts: 1
#
# URL: https://drive.google.com/uc?export=view&id=1wf96PVDn8hU6l30t82Wnbj0Fsk7St-sX.png
#   Type: download_error
#   Error: HTTP 404
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/nlp/nlp-introduction/tokenization/aperswithcode.com/method/wordpiece
#   Type: http_error
#   Error: Page not found
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/lectures/motion-planning-cars/imitation-learning
#   Type: http_error
#   Error: Page not found
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/assignments/topics/mle/gaussian/mle-gmm-sgd.ipynb
#   Type: http_error
#   Error: Page not found
#   Attempts: 1
#
# URL: https://pantelis.github.io/aiml-common/assignments/topics/sports-analytics/basketball/index.ipynb
#   Type: http_error
#   Error: Page not found
#   Attempts: 1

# %% [markdown]
# ## 6. Sample Page Content
#
# View a sample of what was extracted from a page.

# %%
# Get a sample page
sample = storage.pages.find_one()

if sample:
    print(f"URL: {sample['url']}")
    print(f"Title: {sample['title']}")
    print(f"\nLinks found:")
    print(f"  Internal: {len(sample['links_found']['internal'])}")
    print(f"  PDFs: {len(sample['links_found']['pdf'])}")
    print(f"  Videos: {len(sample['links_found']['video'])}")
    print(f"  Images: {len(sample['links_found']['image'])}")
    print(f"\nContent preview (first 500 chars):")
    print("-" * 40)
    print(sample['content'][:500])
else:
    print("No pages ingested yet. Run the crawler first.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Get a sample page
# ----> 2 sample = storage.pages.find_one()
#       4 if sample:
#       5     print(f"URL: {sample['url']}")
#
# NameError: name 'storage' is not defined

# %% [markdown]
# ## 7. MongoDB Queries (Direct Access)
#
# For more advanced queries, you can use the collections directly.

# %%
# Example: Find all pages that link to PDFs
pages_with_pdfs = storage.pages.find(
    {"links_found.pdf": {"$ne": []}},
    {"url": 1, "title": 1, "links_found.pdf": 1}
)

print("Pages that link to PDFs:")
for page in pages_with_pdfs:
    print(f"\n{page['title']}")
    print(f"  URL: {page['url']}")
    print(f"  PDFs: {len(page['links_found']['pdf'])}")
# Out:
# Pages that link to PDFs:
#
# Kinematics – Engineering AI Agents
#   URL: https://pantelis.github.io/book/kinematics/index.html
#   PDFs: 3
#
# Maximum Likelihood (ML) Estimation of conditional models – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/optimization/maximum-likelihood/conditional_maximum_likelihood.html
#   PDFs: 1
#
# Introduction to Backpropagation – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/dnn/backprop-intro/index.html
#   PDFs: 1
#
# Backpropagation in Deep Neural Networks – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/dnn/backprop-dnn/index.html
#   PDFs: 2
#
# Data Preprocessing – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/optimization/whitening/index.html
#   PDFs: 1
#
# Covariance and Correlation Matrices – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/optimization/whitening/corr-cov-matrix.html
#   PDFs: 2
#
# Regularization in Deep Neural Networks – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/optimization/regularization/index.html
#   PDFs: 2
#
# Introduction to Transfer Learning – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/transfer-learning/transfer-learning-introduction.html
#   PDFs: 1
#
# CNN Layers – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/cnn/cnn-layers/index.html
#   PDFs: 2
#
# index – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/cnn/cnn-example-architectures/index.html
#   PDFs: 1
#
# Feature Extraction via Residual Networks – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/scene-understanding/feature-extraction-resnet/index.html
#   PDFs: 2
#
# index – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/scene-understanding/scene-understanding-intro/index.html
#   PDFs: 1
#
# NMS Example – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/scene-understanding/object-detection/rcnn/index.html
#   PDFs: 1
#
# Configuration-space - study – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/kinematics/configuration-space/lynch.html
#   PDFs: 1
#
# Rigid-body motions - study – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/kinematics/motion-representations/lynch.html
#   PDFs: 1
#
# Wheeled robots - study – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/kinematics/wheeled-robots/lynch.html
#   PDFs: 1
#
# Word2Vec Embeddings – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/nlp/nlp-introduction/word2vec/index.html
#   PDFs: 1
#
# Word2Vec Tensorflow Tutorial – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/nlp/nlp-introduction/word2vec/word2vec_tensorflow_tutorial.html
#   PDFs: 3
#
# index – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/rnn/simple-rnn/index.html
#   PDFs: 2
#
# index – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/rnn/lstm/index.html
#   PDFs: 2
#
# Example of an RNN Language Model – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/nlp/language-models/simple-rnn-language-model/index.html
#   PDFs: 1
#
# index – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/nlp/nmt/nmt-intro/index.html
#   PDFs: 1
#
# Planning Domain Definition Language (PDDL) – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/planning/task-planning/pddl/index.html
#   PDFs: 2
#
# Forward Search Algorithms – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/planning/global-planning/search/forward-search/index.html
#   PDFs: 1
#
# Markov Decision Processes – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/mdp/index.html
#   PDFs: 1
#
# index – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/ml-math/index.html
#   PDFs: 1
#
# index – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/ml-math/probability/index.html
#   PDFs: 1
#
# index – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/ml-math/linear-algebra/index.html
#   PDFs: 1
#
# index – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/ml-math/calculus/index.html
#   PDFs: 1
#
# Learn Python – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/python/index.html
#   PDFs: 2
#
# Assignment 1 (grad) – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/assignments/main/ai-fall-2025/assignment-1-grad.html
#   PDFs: 1
#
# Zhang’s Camera Calibration Method – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/lectures/sensor-models/cameras/zhang-calibration-alg.html
#   PDFs: 2
#
# mle-gmm-sgd – Engineering AI Agents
#   URL: https://pantelis.github.io/aiml-common/assignments/topics/mle/gaussian/mle-gmm-sgd-preview.html
#   PDFs: 1

# %%
storage = Storage(
    mongo_uri='mongodb://erica:erica_password_123@mongodb:27017/',
    db_name='erica'
)

# Run this to see what's pending
stats = storage.get_stats()
print(f"PDFs to process: {stats['resources']['by_type']['pdf']}")
print(f"Videos to process: {stats['resources']['by_type']['video']}")

# Preview some
pdfs = list(storage.resources.find({"resource_type": "pdf"}, {"url": 1}).limit(5))
videos = list(storage.resources.find({"resource_type": "video"}, {"url": 1}).limit(5))

print("\nSample PDFs:")
for p in pdfs:
    print(f"  {p['url']}")

print("\nSample Videos:")
for v in videos:
    print(f"  {v['url']}")
# Out:
# PDFs to process: 42
# Videos to process: 11
#
# Sample PDFs:
#   https://pantelis.github.io/book/kinematics/assets/pdf/lynch-config-space.pdf
#   https://pantelis.github.io/assets/pdf/lynch-body-motions.pdf
#   https://pantelis.github.io/assets/pdf/lynch-wheeled-robots.pdf
#   https://pantelis.github.io/aiml-common/lectures/optimization/maximum-likelihood/notescs6140linearregression.pdf
#   http://cs231n.stanford.edu/handouts/derivatives.pdf
#
# Sample Videos:
#   https://www.youtube.com/watch?v=WCUNPb-5EYI
#   https://www.youtube.com/watch?v=6niqTuYFZLQ&t=521s
#   https://youtu.be/_NOVa4i7Us8?list=PL1Q0jeuU6XppS_r2Sa9fzVanpbXKqLsYS&t=384
#   https://www.youtube.com/watch?v=2pWv7GOvuf0&list=PLqYmG7hTraZDM-OYHWgPebj2MfCFzFObQ
#   https://www.youtube.com/watch?v=Nd1-UUMVfz4&list=PLqYmG7hTraZDM-OYHWgPebj2MfCFzFObQ&index=3

# %%
from src.ingestion import PDFProcessor, Storage

storage = Storage(mongo_uri='mongodb://erica:erica_password_123@mongodb:27017/')
pdf_processor = PDFProcessor(storage=storage)
pdf_processor.process_all_pending()
# Out:
# [INFO] Processing 0 PDFs...
# [INFO] PDF processing complete. Success: 0, Failed: 0

# %%
# Reset failed videos to try again
storage.resources.update_many(
    {"resource_type": "video", "status": "failed"},
    {"$set": {"status": "pending"}}
)

# Then run the processor again
from src.ingestion import YouTubeProcessor
yt_processor = YouTubeProcessor(storage=storage)
yt_processor.process_all_pending()
# Out:
# [INFO] Processing 11 YouTube videos...
# [INFO] [1/11] https://www.youtube.com/watch?v=WCUNPb-5EYI
# [INFO]   Extracted 21179 chars (en language)
# [INFO] [2/11] https://www.youtube.com/watch?v=6niqTuYFZLQ&t=521s
# [INFO]   Extracted 78759 chars (en language)
# [INFO] [3/11] https://youtu.be/_NOVa4i7Us8?list=PL1Q0jeuU6XppS_r2Sa9fzVanpbXKqLsYS&t=384
# [INFO]   Extracted 12351 chars (en language)
# [INFO] [4/11] https://www.youtube.com/watch?v=2pWv7GOvuf0&list=PLqYmG7hTraZDM-OYHWgPebj2MfCFzFObQ
# [INFO]   Extracted 95211 chars (en language)
# [INFO] [5/11] https://www.youtube.com/watch?v=Nd1-UUMVfz4&list=PLqYmG7hTraZDM-OYHWgPebj2MfCFzFObQ&index=3
# [INFO]   Extracted 101324 chars (en language)
# [INFO] [6/11] https://www.youtube.com/watch?v=x6wsTFnU3eY
# [INFO]   Extracted 45175 chars (en language)
# [INFO] [7/11] https://www.youtube.com/watch?v=MMxMeX5emUA
# [INFO]   Extracted 5560 chars (en language)
# [INFO] [8/11] https://www.youtube.com/watch?v=DiOxbYTLXX8
# [INFO]   Extracted 11799 chars (en language)
# [INFO] [9/11] https://www.youtube.com/watch?v=Cx5Z-OslNWE&list=PLUl4u3cNGP63oMNUHXqIUcrkS2PivhN3k
# [INFO]   Extracted 4263 chars (en language)
# [INFO] [10/11] https://www.youtube.com/playlist?list=PLZHQObOWTQDPD3MizzM2xVFitgF8hE_ab
# [WARNING]   Could not extract video ID from URL
# [INFO] [11/11] https://www.youtube.com/watch?v=hzaG2Uq60uw
# [INFO]   Extracted 3019 chars (en language)
# [INFO] YouTube processing complete. Success: 10, Failed: 1

# %%
# Check a processed PDF
pdf = storage.resources.find_one({"resource_type": "pdf", "status": "ingested"})
print(f"PDF: {pdf['url']}")
print(f"Pages: {pdf['metadata'].get('page_count')}")
print(f"Content preview: {pdf.get('content', '')[:500]}")

# Check a processed video
video = storage.resources.find_one({"resource_type": "video", "status": "ingested"})
print(f"Video: {video['url']}")
print(f"Content preview: {video.get('content', '')[:500]}")
# Out:
# PDF: https://pantelis.github.io/assets/pdf/lynch-body-motions.pdf
# Pages: 78
# Content preview: Chapter 3
# Rigid-Body Motions
# In the previous chapter, we saw that a minimum of six numbers is needed
# to specify the position and orientation of a rigid body in three-dimensional
# physical space. In this chapter we develop a systematic way to describe a rigid
# body’s position and orientation which relies on attaching a reference frame to
# the body. The conﬁguration of this frame with respect to a ﬁxed reference frame
# is then represented as a 4 × 4 matrix. This matrix is an example of an implicit
# rep
# Video: https://www.youtube.com/watch?v=WCUNPb-5EYI
# Content preview: applications of machine learning have gotten a lot of traction in the last few years there's a couple of big categories that have had wins one is identifying pictures the equivalent of finding cats on the internet and any problem that can be made to look like that and the other is sequence to sequence translation this can be speech to text or one language to another most of the former are done with convolutional neural networks most of the latter are done with recurrent neural networks uh partic

# %%
# Cleanup
storage.close()
print("Storage connection closed.")
# Out:
# Storage connection closed.
